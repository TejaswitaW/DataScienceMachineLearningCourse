# %%
import pandas as pd

# %%
# creating pandas dataframe
original_dataframe=pd.read_csv("IMDB-Movie-Data.csv")

# %%
# it removes original default index
modified_dataframe=pd.read_csv("IMDB-Movie-Data.csv",index_col="Title")

# %%
# can see some number of rows
modified_dataframe.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
# shape attribute
modified_dataframe.shape
# Out:
# (1000, 11)

# %%
# getting dataset attributes
original_dataframe.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
#df.rows() error

# %%
# getting dataset attributes
original_dataframe.keys()
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
# can see some data points
original_dataframe.head(3)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# ...

# %%
# can observe last data points
original_dataframe.tail(3)
# Out:
#      Rank                   Title                  Genre  \
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 997                 98     6.2  70699               58.01       50.0
# ...

# %%
# getting statistics of data
original_dataframe.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
# getting details of data
original_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
# creating dataframe which contains duplicate values
duplicated_dataframe=original_dataframe.append(original_dataframe)

# %%
# getting some rows of duplicated_dataframe
duplicated_dataframe.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
# getting number of rows and columns in duplicated_dataframe
duplicated_dataframe.shape
# Out:
# (2000, 12)

# %%
# getting details of dataframe data
duplicated_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                2000 non-null   int64
#  1   Title               2000 non-null   object
#  2   Genre               2000 non-null   object
#  3   Description         2000 non-null   object
#  4   Director            2000 non-null   object
#  5   Actors              2000 non-null   object
#  6   Year                2000 non-null   int64
#  7   Runtime (Minutes)   2000 non-null   int64
#  8   Rating              2000 non-null   float64
#  9   Votes               2000 non-null   int64
#  10  Revenue (Millions)  1744 non-null   float64
#  11  Metascore           1872 non-null   float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 203.1+ KB

# %%
#df2=df2.drop_duplicates()
# no use of duplicates,while processing data, so we need to delete duplicate data
# index should be same of both original and duplicate data then duplicate data will get removed
duplicated_dataframe.drop_duplicates(keep=False)
duplicated_dataframe
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# after deletion of duplicate data points from duplicated_dataframe
duplicated_dataframe.shape
# Out:
# (2000, 12)

# %%
duplicated_dataframe=original_dataframe.append(original_dataframe)
# inplace=True makes changes in original input dataframe
duplicated_dataframe.drop_duplicates(inplace=True,keep=False)

# %%
duplicated_dataframe.shape
# Out:
# (0, 12)

# %%
#df["Revenue (Millions)"].isnull

# %%
original_dataframe.shape
# Out:
# (1000, 12)

# %% [raw]
# groupby() function is used to split the data into groups based on some criteria. pandas objects can be split on any of their axes. The abstract definition of grouping is to provide a mapping of labels to group names.

# %%
groupby_object = original_dataframe.groupby("Title")

# %%
groupby_object.first()
# Out:
#                       Rank                       Genre  \
# Title
# (500) Days of Summer   508        Comedy,Drama,Romance
# 10 Cloverfield Lane    119        Drama,Horror,Mystery
# 10 Years               697        Comedy,Drama,Romance
# 12 Years a Slave       112     Biography,Drama,History
# 127 Hours              818   Adventure,Biography,Drama
# ...                    ...                         ...
# Zipper                 545              Drama,Thriller
# Zodiac                 278         Crime,Drama,History
# Zombieland             364     Adventure,Comedy,Horror
# Zoolander 2            432                      Comedy
# Zootopia                75  Animation,Adventure,Comedy
#
#                                                             Description  \
# Title
# (500) Days of Summer  An offbeat romantic comedy about a woman who d...
# 10 Cloverfield Lane   After getting in a car accident, a woman is he...
# ...

# %%
groupby_object = original_dataframe.groupby("Genre")

# %%
groupby_object.first()
# Out:
#                             Rank                  Title  \
# Genre
# Action                       124   Boyka: Undisputed IV
# Action,Adventure             285               Hercules
# Action,Adventure,Biography     9     The Lost City of Z
# Action,Adventure,Comedy       34               Deadpool
# Action,Adventure,Crime       150                Inferno
# ...                          ...                    ...
# Romance,Sci-Fi,Thriller      707  The Adjustment Bureau
# Sci-Fi                       184                Realive
# Sci-Fi,Thriller              513          The Happening
# Thriller                     283            Death Proof
# Thriller,War                 161                   Mine
#
#                                                                   Description  \
# Genre
# Action                      In the fourth installment of the fighting fran...
# Action,Adventure            Having endured his legendary twelve labors, He...
# ...

# %%
groupby_object = original_dataframe.groupby("Year")

# %%
groupby_object.first()
# Out:
#       Rank                                        Title  \
# Year
# 2006    65                                 The Prestige
# 2007    40                                    5- 25- 77
# 2008    55                              The Dark Knight
# 2009    78                         Inglourious Basterds
# 2010    81                                    Inception
# 2011    46  Pirates of the Caribbean: On Stranger Tides
# 2012     2                                   Prometheus
# 2013    83                      The Wolf of Wall Street
# 2014     1                      Guardians of the Galaxy
# 2015    27                      Bahubali: The Beginning
# 2016     3                                        Split
#
#                          Genre  \
# Year
# 2006      Drama,Mystery,Sci-Fi
# 2007              Comedy,Drama
# 2008        Action,Crime,Drama
# 2009       Adventure,Drama,War
# 2010   Action,Adventure,Sci-Fi
# 2011  Action,Adventure,Fantasy
# 2012  Adventure,Mystery,Sci-Fi
# ...

# %%
groupby_object.first().count
# Out:
# <bound method DataFrame.count of       Rank                                        Title  \
# Year
# 2006    65                                 The Prestige
# 2007    40                                    5- 25- 77
# 2008    55                              The Dark Knight
# 2009    78                         Inglourious Basterds
# 2010    81                                    Inception
# 2011    46  Pirates of the Caribbean: On Stranger Tides
# 2012     2                                   Prometheus
# 2013    83                      The Wolf of Wall Street
# 2014     1                      Guardians of the Galaxy
# 2015    27                      Bahubali: The Beginning
# 2016     3                                        Split
#
#                          Genre  \
# Year
# 2006      Drama,Mystery,Sci-Fi
# 2007              Comedy,Drama
# 2008        Action,Crime,Drama
# 2009       Adventure,Drama,War
# 2010   Action,Adventure,Sci-Fi
# 2011  Action,Adventure,Fantasy
# ...

# %%
original_dataframe["Title"].count
# Out:
# <bound method Series.count of 0      Guardians of the Galaxy
# 1                   Prometheus
# 2                        Split
# 3                         Sing
# 4                Suicide Squad
#                 ...
# 995       Secret in Their Eyes
# 996            Hostel: Part II
# 997     Step Up 2: The Streets
# 998               Search Party
# 999                 Nine Lives
# Name: Title, Length: 1000, dtype: object>

# %%
#original_dataframe.count

# %%
#groupby_object.get_group("Genre")

# %%
original_dataframe
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
original_dataframe.mean()
# Out:
# Rank                     500.500000
# Year                    2012.783000
# Runtime (Minutes)        113.172000
# Rating                     6.723200
# Votes                 169808.255000
# Revenue (Millions)        82.956376
# Metascore                 58.985043
# dtype: float64

# %%
original_dataframe.median()
# Out:
# Rank                     500.500
# Year                    2014.000
# Runtime (Minutes)        111.000
# Rating                     6.800
# Votes                 110799.000
# Revenue (Millions)        47.985
# Metascore                 59.500
# dtype: float64

# %%
original_dataframe.mode()
# Out:
#      Rank     Title                    Genre  \
# 0       1  The Host  Action,Adventure,Sci-Fi
# 1       2       NaN                      NaN
# 2       3       NaN                      NaN
# 3       4       NaN                      NaN
# 4       5       NaN                      NaN
# ..    ...       ...                      ...
# 995   996       NaN                      NaN
# 996   997       NaN                      NaN
# 997   998       NaN                      NaN
# 998   999       NaN                      NaN
# 999  1000       NaN                      NaN
#
#                                            Description      Director  \
# 0    "21" is the fact-based story about six MIT stu...  Ridley Scott
# 1    "Mr. Church" tells the story of a unique frien...           NaN
# 2    "The Thinning" takes place in a post-apocalypt...           NaN
# 3    #1 NASCAR driver Ricky Bobby stays atop the he...           NaN
# 4    12-year-old orphan Peter is spirited away to t...           NaN
# ...

# %%
original_dataframe.std()
# Out:
# Rank                     288.819436
# Year                       3.205962
# Runtime (Minutes)         18.810908
# Rating                     0.945429
# Votes                 188762.647518
# Revenue (Millions)       103.253540
# Metascore                 17.194757
# dtype: float64

# %%
original_dataframe.min()
# Out:
# Rank                                                                  1
# Title                                              (500) Days of Summer
# Genre                                                            Action
# Description           "21" is the fact-based story about six MIT stu...
# Director                                                     Aamir Khan
# Actors                Aamir Khan, Anushka Sharma, Sanjay Dutt,Boman ...
# Year                                                               2006
# Runtime (Minutes)                                                    66
# Rating                                                              1.9
# Votes                                                                61
# Revenue (Millions)                                                    0
# Metascore                                                            11
# dtype: object

# %%
original_dataframe.max()
# Out:
# Rank                                                               1000
# Title                                                          Zootopia
# Genre                                                      Thriller,War
# Description           Young, up-and-coming martial artist, Bruce Lee...
# Director                                                  Zackary Adler
# Actors                Zooey Deschanel, Joseph Gordon-Levitt, Geoffre...
# Year                                                               2016
# Runtime (Minutes)                                                   191
# Rating                                                                9
# Votes                                                           1791916
# Revenue (Millions)                                               936.63
# Metascore                                                           100
# dtype: object

# %%
#df.abs()# cant take string

# %%
original_dataframe.prod()
# Out:
# Rank                  0.0
# Year                  0.0
# Runtime (Minutes)     0.0
# Rating                inf
# Votes                 0.0
# Revenue (Millions)    NaN
# Metascore             inf
# dtype: float64

# %%
original_dataframe.cumsum()
# Out:
#        Rank                                              Title  \
# 0         1                            Guardians of the Galaxy
# 1         3                  Guardians of the GalaxyPrometheus
# 2         6             Guardians of the GalaxyPrometheusSplit
# 3        10         Guardians of the GalaxyPrometheusSplitSing
# 4        15  Guardians of the GalaxyPrometheusSplitSingSuic...
# ..      ...                                                ...
# 995  496506  Guardians of the GalaxyPrometheusSplitSingSuic...
# 996  497503  Guardians of the GalaxyPrometheusSplitSingSuic...
# 997  498501  Guardians of the GalaxyPrometheusSplitSingSuic...
# 998  499500  Guardians of the GalaxyPrometheusSplitSingSuic...
# 999  500500  Guardians of the GalaxyPrometheusSplitSingSuic...
#
#                                                  Genre  \
# 0                              Action,Adventure,Sci-Fi
# 1      Action,Adventure,Sci-FiAdventure,Mystery,Sci-Fi
# ...

# %%
#df.cumprod()# cant take string input

# %%
original_dataframe.rename(columns={'Runtime (Minutes)':'Runtime','Revenue (Millions)':'Revenue_millions'},inplace=True)

# %%
original_dataframe.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime', 'Rating', 'Votes', 'Revenue_millions', 'Metascore'],
#       dtype='object')

# %%
# converting column names into lower case letters
original_dataframe.columns=[col.lower() for col in original_dataframe]

# %%
original_dataframe.keys()
# Out:
# Index(['rank', 'title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime', 'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')

# %%
# getting data based on some boolean condition
condition=original_dataframe["director"]=="Ridley Scott"# it is like filter
condition.head()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: director, dtype: bool

# %%
#df[df["director"]=="Ridley Scott" or df["director"]=="Christophe Lourdelet"]
# gives data points with director "Ridley Scott"
original_dataframe[original_dataframe["director"]=="Ridley Scott"] 
#condition
# Out:
#      rank                   title                     genre  \
# 1       2              Prometheus  Adventure,Mystery,Sci-Fi
# 102   103             The Martian    Adventure,Drama,Sci-Fi
# 387   388              Robin Hood    Action,Adventure,Drama
# 470   471       American Gangster     Biography,Crime,Drama
# 516   517  Exodus: Gods and Kings    Action,Adventure,Drama
# 521   522           The Counselor      Crime,Drama,Thriller
# 530   531             A Good Year      Comedy,Drama,Romance
# 737   738            Body of Lies      Action,Drama,Romance
#
#                                            description      director  \
# 1    Following clues to the origin of mankind, a te...  Ridley Scott
# 102  An astronaut becomes stranded on Mars after hi...  Ridley Scott
# 387  In 12th century England, Robin and his band of...  Ridley Scott
# 470  In 1970s America, a detective works to bring d...  Ridley Scott
# 516  The defiant leader Moses rises up against the ...  Ridley Scott
# ...

# %%
# gives data points whose director is Ridley Scott or Christophe Lourdelet
original_dataframe[(original_dataframe["director"]=="Ridley Scott") | \
                   (original_dataframe["director"]=="Christophe Lourdelet")].head()
# Out:
#      rank              title                     genre  \
# 1       2         Prometheus  Adventure,Mystery,Sci-Fi
# 3       4               Sing   Animation,Comedy,Family
# 102   103        The Martian    Adventure,Drama,Sci-Fi
# 387   388         Robin Hood    Action,Adventure,Drama
# 470   471  American Gangster     Biography,Crime,Drama
#
#                                            description              director  \
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# 3    In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 102  An astronaut becomes stranded on Mars after hi...          Ridley Scott
# 387  In 12th century England, Robin and his band of...          Ridley Scott
# 470  In 1970s America, a detective works to bring d...          Ridley Scott
#
#                                                 actors  year  runtime  rating  \
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012      124     7.0
# ...

# %%
# gives data points whose director is Ridley Scott or Christophe Lourdelet
# getting ratings more than 5.7
original_dataframe[(original_dataframe["director"]=="Ridley Scott")\
                   | (original_dataframe["director"]=="Christophe Lourdelet") & (original_dataframe["rating"]>5.7)]
# Out:
#      rank                   title                     genre  \
# 1       2              Prometheus  Adventure,Mystery,Sci-Fi
# 3       4                    Sing   Animation,Comedy,Family
# 102   103             The Martian    Adventure,Drama,Sci-Fi
# 387   388              Robin Hood    Action,Adventure,Drama
# 470   471       American Gangster     Biography,Crime,Drama
# 516   517  Exodus: Gods and Kings    Action,Adventure,Drama
# 521   522           The Counselor      Crime,Drama,Thriller
# 530   531             A Good Year      Comedy,Drama,Romance
# 737   738            Body of Lies      Action,Drama,Romance
#
#                                            description              director  \
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# 3    In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 102  An astronaut becomes stranded on Mars after hi...          Ridley Scott
# ...

# %%
# getting data points with between 2005 to 2010 and rating greater than 5 
original_dataframe[(original_dataframe["year"]>=2005) & (original_dataframe["year"]<=2010) &\
                   (original_dataframe["rating"]>5)]
# Out:
#      rank                                     title                     genre  \
# 39     40                                 5- 25- 77              Comedy,Drama
# 54     55                           The Dark Knight        Action,Crime,Drama
# 64     65                              The Prestige      Drama,Mystery,Sci-Fi
# 75     76  Pirates of the Caribbean: At World's End  Action,Adventure,Fantasy
# 77     78                      Inglourious Basterds       Adventure,Drama,War
# ..    ...                                       ...                       ...
# 990   991            Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                          Taare Zameen Par        Drama,Family,Music
# 993   994                  Resident Evil: Afterlife   Action,Adventure,Horror
# 996   997                           Hostel: Part II                    Horror
# 997   998                    Step Up 2: The Streets       Drama,Music,Romance
#
# ...

# %%
original_dataframe[(original_dataframe["year"]>2005) & (original_dataframe["year"]<2010)\
                   & (original_dataframe["rating"]>5)]
# Out:
#      rank                                     title                     genre  \
# 39     40                                 5- 25- 77              Comedy,Drama
# 54     55                           The Dark Knight        Action,Crime,Drama
# 64     65                              The Prestige      Drama,Mystery,Sci-Fi
# 75     76  Pirates of the Caribbean: At World's End  Action,Adventure,Fantasy
# 77     78                      Inglourious Basterds       Adventure,Drama,War
# ..    ...                                       ...                       ...
# 988   989                                   Martyrs                    Horror
# 990   991            Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                          Taare Zameen Par        Drama,Family,Music
# 996   997                           Hostel: Part II                    Horror
# 997   998                    Step Up 2: The Streets       Drama,Music,Romance
#
# ...
