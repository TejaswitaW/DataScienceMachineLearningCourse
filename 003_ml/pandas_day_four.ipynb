# %% [markdown]
# ### EDA and Data Visualization

# %%
# import required library
import pandas as pd

# %%
# creating pandas dataframe
original_dataframe=pd.read_csv("IMDB-Movie-Data.csv")

# %%
# converting all column names into lower case
original_dataframe.columns=[col.lower() for col in original_dataframe]

# %%
#original_dataframe.info()

# %% [raw]
# The value_counts() function is used to get a Series containing counts of unique values.
# The resulting object will be in descending order so that the first element is the most frequently-occurring element. Excludes NA values by default.

# %%
# here we are getting unique values of "genre"
# total we got 207 genres
original_dataframe["genre"].value_counts()
# Out:
# Action,Adventure,Sci-Fi     50
# Drama                       48
# Comedy,Drama,Romance        35
# Comedy                      32
# Drama,Romance               31
#                             ..
# Drama,Fantasy,Musical        1
# Drama,Fantasy,Mystery        1
# Comedy,Horror,Romance        1
# Adventure,Horror,Mystery     1
# Action,Comedy,Mystery        1
# Name: genre, Length: 207, dtype: int64

# %%
# total count non-NA cells for given column or row
original_dataframe["genre"].value_counts().count()
# Out:
# 207

# %%
# getting director name and movies count of each director
original_dataframe["director"].value_counts()
# Out:
# Ridley Scott          8
# David Yates           6
# Paul W.S. Anderson    6
# M. Night Shyamalan    6
# Michael Bay           6
#                      ..
# Biyi Bandele          1
# Werner Herzog         1
# Rian Johnson          1
# Filip Renc            1
# Lisa Addario          1
# Name: director, Length: 644, dtype: int64

# %% [raw]
# Group DataFrame using a mapper or by a Series of columns.A groupby operation involves some combination of splitting the object, applying a function, and combining the results. This can be used to group large amounts of data and compute operations on these groups.

# %%
# it returns dictionary which contain group name as key and group label as value
# here labels are indices of rows 
original_dataframe.groupby("genre").groups
# Out:
# {'Action': Int64Index([123, 580], dtype='int64'),
#  'Action,Adventure': Int64Index([284, 344, 368], dtype='int64'),
#  'Action,Adventure,Biography': Int64Index([8, 558], dtype='int64'),
#  'Action,Adventure,Comedy': Int64Index([33, 65, 104, 166, 179, 217, 264, 496, 537, 597, 657, 728, 810,
#              833],
#             dtype='int64'),
#  'Action,Adventure,Crime': Int64Index([149, 163, 281, 414, 465, 901], dtype='int64'),
#  'Action,Adventure,Drama': Int64Index([ 26,  29, 107, 176, 210, 232, 234, 369, 385, 387, 491, 516, 564,
#              693, 718, 856, 880, 920],
#             dtype='int64'),
#  'Action,Adventure,Family': Int64Index([175, 228, 581, 787], dtype='int64'),
#  'Action,Adventure,Fantasy': Int64Index([  4,   5,  37,  45,  50,  51,  75,  78,  87,  91, 101, 214, 215,
#              294, 325, 355, 575, 609, 626, 739, 758, 767, 806, 827, 871, 879,
#              990],
#             dtype='int64'),
#  'Action,Adventure,Horror': Int64Index([432, 993], dtype='int64'),
# ...

# %%
#original_dataframe.head()

# %%
# wherever null value in dataset it gives True for that value
original_dataframe.isnull()
# Out:
#       rank  title  genre  description  director  actors   year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      runtime (minutes)  rating  votes  revenue (millions)  metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %% [raw]
# sum() function is used to return the sum of the values for the requested axis by the user. If the input value is an index axis, then it will add all the values in a column and works same for all the columns. It returns a series that contains the sum of all the values in each column.

# %%
# here it will gives total number of null values in each column
original_dataframe.isnull().sum()
# Out:
# rank                    0
# title                   0
# genre                   0
# description             0
# director                0
# actors                  0
# year                    0
# runtime (minutes)       0
# rating                  0
# votes                   0
# revenue (millions)    128
# metascore              64
# dtype: int64

# %% [raw]
# .info() in Pandas, it will return information about the dataframe including the data types of each column and memory usage of the entire data.

# %%
# getting information about the dataframe
original_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   rank                1000 non-null   int64
#  1   title               1000 non-null   object
#  2   genre               1000 non-null   object
#  3   description         1000 non-null   object
#  4   director            1000 non-null   object
#  5   actors              1000 non-null   object
#  6   year                1000 non-null   int64
#  7   runtime (minutes)   1000 non-null   int64
#  8   rating              1000 non-null   float64
#  9   votes               1000 non-null   int64
#  10  revenue (millions)  872 non-null    float64
#  11  metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [raw]
# The dropna() function is used to remove missing values. Determine if rows or columns which contain missing values are removed. 0, or 'index' : Drop rows which contain missing values. 1, or 'columns' : Drop columns which contain missing value

# %%
# here we are creating new dataframe
# which does not contain any null value
new_dataframe=original_dataframe.dropna()

# %%
# after dropna on original_dataframe , newly created dataframe's info
# observe the difference in previous info and current info
new_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   rank                838 non-null    int64
#  1   title               838 non-null    object
#  2   genre               838 non-null    object
#  3   description         838 non-null    object
#  4   director            838 non-null    object
#  5   actors              838 non-null    object
#  6   year                838 non-null    int64
#  7   runtime (minutes)   838 non-null    int64
#  8   rating              838 non-null    float64
#  9   votes               838 non-null    int64
#  10  revenue (millions)  838 non-null    float64
#  11  metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 85.1+ KB

# %%
new_dataframe_column=original_dataframe.dropna(axis=1)

# %%
# for dropna specifying axis
# default axis is axis 0
# it deletes columns which contain null values, 
# so it has deleted "revenue (millions)" and "metascore"
# observe the shape of modified dateframe,contains two less columns
# observe the shape difference
new_dataframe_column.shape
# Out:
# (1000, 10)

# %%
original_dataframe.shape
# Out:
# (1000, 12)

# %%
new_dataframe_column.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rank               1000 non-null   int64
#  1   title              1000 non-null   object
#  2   genre              1000 non-null   object
#  3   description        1000 non-null   object
#  4   director           1000 non-null   object
#  5   actors             1000 non-null   object
#  6   year               1000 non-null   int64
#  7   runtime (minutes)  1000 non-null   int64
#  8   rating             1000 non-null   float64
#  9   votes              1000 non-null   int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 78.2+ KB

# %% [markdown]
# #### Handling Missing Values

# %%
# we got individual column, which is series
individual_series=original_dataframe["revenue (millions)"]
print(individual_series)
print()
print("Type of above data structure is : ")
print(type(individual_series))
# Out:
# 0      333.13
# 1      126.46
# 2      138.12
# 3      270.32
# 4      325.02
#         ...
# 995       NaN
# 996     17.54
# 997     58.01
# 998       NaN
# 999     19.64
# Name: revenue (millions), Length: 1000, dtype: float64
#
# Type of above data structure is :
# <class 'pandas.core.series.Series'>

# %%
# getting mean value of "revenue (millions)"
mean_value=original_dataframe["revenue (millions)"].mean()
mean_value
# Out:
# 82.95637614678898

# %%
# filling null values in "revenue (millions)" with its mean value 
original_dataframe["revenue (millions)"].fillna(mean_value,inplace=True)

# %%
# observe after filling null values with mean value in original_dataframe
# we get non_null value count in "revenue (millions)" as 1000
# because we have filled null values with mean value
original_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   rank                1000 non-null   int64
#  1   title               1000 non-null   object
#  2   genre               1000 non-null   object
#  3   description         1000 non-null   object
#  4   director            1000 non-null   object
#  5   actors              1000 non-null   object
#  6   year                1000 non-null   int64
#  7   runtime (minutes)   1000 non-null   int64
#  8   rating              1000 non-null   float64
#  9   votes               1000 non-null   int64
#  10  revenue (millions)  1000 non-null   float64
#  11  metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
# check with sum() function total null values in "revenue (millions)"
# now it is 0
original_dataframe.isnull().sum()
# Out:
# rank                   0
# title                  0
# genre                  0
# description            0
# director               0
# actors                 0
# year                   0
# runtime (minutes)      0
# rating                 0
# votes                  0
# revenue (millions)     0
# metascore             64
# dtype: int64

# %%
# original_dataframe.head()

# %%
original_dataframe.describe(include="object")
# Out:
#            title                    genre  \
# count       1000                     1000
# unique       999                      207
# top     The Host  Action,Adventure,Sci-Fi
# freq           2                       50
#
#                                               description      director  \
# count                                                1000          1000
# unique                                               1000           644
# top     A scientist's drive for artificial intelligenc...  Ridley Scott
# freq                                                    1             8
#
#                                                    actors
# count                                                1000
# unique                                                996
# top     Daniel Radcliffe, Emma Watson, Rupert Grint, M...
# freq                                                    2

# %%
# we need to replace categorical data with numerical values
# because machine can process only numerical data
# create dictionary key,value to replace categorical data
# it gives attributes with categorical values 
new_my_df=original_dataframe.select_dtypes(include=["object"]).copy()
new_my_df
# Out:
#                        title                     genre  \
# 0    Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1                 Prometheus  Adventure,Mystery,Sci-Fi
# 2                      Split           Horror,Thriller
# 3                       Sing   Animation,Comedy,Family
# 4              Suicide Squad  Action,Adventure,Fantasy
# ..                       ...                       ...
# 995     Secret in Their Eyes       Crime,Drama,Mystery
# 996          Hostel: Part II                    Horror
# 997   Step Up 2: The Streets       Drama,Music,Romance
# 998             Search Party          Adventure,Comedy
# 999               Nine Lives     Comedy,Family,Fantasy
#
#                                            description              director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %% [markdown]
# #### Data Visualisation

# %% [markdown]
# #### Why data visualisation is important?
# ###### 1.Data Understanding.
# ###### 2.To get more information from data.
# ###### 3.Report Generation.
# ###### 4.Outlier detection.
# ###### 5. Get to know how data is distributed.
# ###### 6.We can apply algorithm on the basis of data distribution to create ML model.

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# histogram 
# plotting histogram of "genre" 
carrier_count=original_dataframe["genre"].value_counts()
sns.set(style="darkgrid")
# show point estimates and confidence intervals as rectangular bars
sns.barplot(carrier_count.index,carrier_count.values,alpha=0.9)
plt.title("Frequency Distribution of Carriers")
plt.ylabel("Number of Occurrences",fontsize=12)
plt.xlabel("Genre",fontsize=12)
plt.show()

# %%
new_dataframe=original_dataframe.copy()

# %%
# LabelEncoder is a class
from sklearn.preprocessing import LabelEncoder
#print(type(LabelEncoder))

# %%
# LabelEncoder() encode target labels with value between 0 and n_classes-1
lb_make = LabelEncoder()
#print(type(lb_make))
#lb_make is an object of LabelEncoder class

# %%
 original_dataframe["genre"].value_counts()
# Out:
# Action,Adventure,Sci-Fi     50
# Drama                       48
# Comedy,Drama,Romance        35
# Comedy                      32
# Drama,Romance               31
#                             ..
# Drama,Fantasy,Musical        1
# Drama,Fantasy,Mystery        1
# Comedy,Horror,Romance        1
# Adventure,Horror,Mystery     1
# Action,Comedy,Mystery        1
# Name: genre, Length: 207, dtype: int64

# %%
# here encoding categorical variable "genre" 
# it labels "genre" from 0,1,2,3....207, observe above cell code
new_dataframe["genre_new"]=lb_make.fit_transform(original_dataframe["genre"])

# %%
#new_dataframe.head()

# %%
# creating copy of original dataframe
new_dataframe=original_dataframe.copy()

# %%
# convert categorical variable into dummy/indicator variables
# one hot encoder
# it creates new 207 columns
# observe the shape of original_dataframe and new_dataframe
new_dataframe=pd.get_dummies(new_dataframe,columns=["genre"],prefix=["genre"])

# %%
# shape of original dataframe
original_dataframe.shape
# Out:
# (1000, 12)

# %%
# shape of new_dataframe which is one hot encoded for genre variable
new_dataframe.shape
# Out:
# (1000, 218)

# %%
new_dataframe.head()
# Out:
#    rank                    title  \
# 0     1  Guardians of the Galaxy
# 1     2               Prometheus
# 2     3                    Split
# 3     4                     Sing
# 4     5            Suicide Squad
#
#                                          description              director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               actors  year  runtime (minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# ...

# %%
# in statistical analysis of dataframe 
# for categorical variable it shows NaN
original_dataframe.describe(include="all")
# Out:
#                rank     title                    genre  \
# count   1000.000000      1000                     1000
# unique          NaN       999                      207
# top             NaN  The Host  Action,Adventure,Sci-Fi
# freq            NaN         2                       50
# mean     500.500000       NaN                      NaN
# std      288.819436       NaN                      NaN
# min        1.000000       NaN                      NaN
# 25%      250.750000       NaN                      NaN
# 50%      500.500000       NaN                      NaN
# 75%      750.250000       NaN                      NaN
# max     1000.000000       NaN                      NaN
#
#                                               description      director  \
# count                                                1000          1000
# unique                                               1000           644
# top     A scientist's drive for artificial intelligenc...  Ridley Scott
# ...

# %%
# we can apply describe() on individual series
original_dataframe["genre"].describe()
# Out:
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: genre, dtype: object

# %% [raw]
# Correlation coefficient is a number between +1 and −1 calculated so as to represent the linear interdependence of two variables or sets of data.
# +ve means positive linear relationship
# -ve means negative linear realtionship
# 0 means no correlation
# 1 means perfectly correlated

# %%
# gives correlation in data attributes
# compute pairwise correlation of columns, excluding NA/null values
original_dataframe.corr()
# Out:
#                         rank      year  runtime (minutes)    rating     votes  \
# rank                1.000000 -0.261605          -0.221739 -0.219555 -0.283876
# year               -0.261605  1.000000          -0.164900 -0.211219 -0.411904
# runtime (minutes)  -0.221739 -0.164900           1.000000  0.392214  0.407062
# rating             -0.219555 -0.211219           0.392214  1.000000  0.511537
# votes              -0.283876 -0.411904           0.407062  0.511537  1.000000
# revenue (millions) -0.252996 -0.117562           0.247834  0.189527  0.607941
# metascore          -0.191869 -0.079305           0.211978  0.631897  0.325684
#
#                     revenue (millions)  metascore
# rank                         -0.252996  -0.191869
# year                         -0.117562  -0.079305
# runtime (minutes)             0.247834   0.211978
# rating                        0.189527   0.631897
# votes                         0.607941   0.325684
# ...

# %%
def rating_function(x):
    """Converts ratings into categorical data"""
    if x>=8.0:
        return "good"
    else:
        return "bad"

# %%
# map,apply,applymap
original_dataframe["rating_category"]=original_dataframe["rating"].apply(rating_function)

# %%
original_dataframe.head()
# Out:
#    rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          description              director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               actors  year  runtime (minutes)  \
# ...

# %%
# we can take subset of dataframe
subset=original_dataframe[["genre","rating"]]

# %%
# cheacking head values of subset
subset.head()
# Out:
#                       genre  rating
# 0   Action,Adventure,Sci-Fi     8.1
# 1  Adventure,Mystery,Sci-Fi     7.0
# 2           Horror,Thriller     7.3
# 3   Animation,Comedy,Family     7.2
# 4  Action,Adventure,Fantasy     6.2

# %% [raw]
# loc is label-based, which means that you have to specify rows and columns based on their row and column labels. iloc is integer index based, so you have to specify rows and columns by their integer index

# %%
#prom=original_dataframe.loc["Promethus":"Sing"]
prom=original_dataframe.loc["Promethus":"Sing"]
prom=original_dataframe.loc["title":"Legend"]
prom
# Out:
# Empty DataFrame
# Columns: [rank, title, genre, description, director, actors, year, runtime (minutes), rating, votes, revenue (millions), metascore, rating_category]
# Index: []

# %%
prom=original_dataframe.iloc[100]
prom
# Out:
# rank                                                                101
# title                                                            Legend
# genre                                             Biography,Crime,Drama
# description           Identical twin gangsters Ronald and Reginald K...
# director                                                Brian Helgeland
# actors                Tom Hardy, Emily Browning, Taron Egerton, Paul...
# year                                                               2015
# runtime (minutes)                                                   132
# rating                                                                7
# votes                                                            108836
# revenue (millions)                                                 1.87
# metascore                                                            55
# rating_category                                                     bad
# Name: 100, dtype: object
